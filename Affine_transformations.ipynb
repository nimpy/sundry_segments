# %%
# on janice, default env

# %%
# TODO do this, but with pytorch (and keras)

# %%
from skimage import transform as tf
import matplotlib.pyplot as plt
import numpy
import imageio

# %%
img = imageio.imread('/home/niaki/Downloads/Lenna.png')

# %%
shear_trans = tf.AffineTransform(shear=-0.2)
scale_trans = tf.AffineTransform(scale=(0.9, 1))
rotate_trans = tf.AffineTransform(rotation=0.2)
tranls_trans = tf.AffineTransform(translation=(10,20))
all_trans = tf.AffineTransform(shear=-0.2, scale=(0.9, 1), rotation=0.2, translation=(10,20))

# %%
mod_img = tf.warp(img, inverse_map=all_trans)

# %%
plt.imshow(mod_img)
