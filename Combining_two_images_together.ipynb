# %%
import imageio
import matplotlib.pyplot as plt

# %%
image1 = imageio.imread("/scratch/data/panel13/clean_inpainted_better1.jpg")
image2 = imageio.imread("/scratch/data/panel13/clean.tif")

# %%
for i in range(912, 1065):
    for j in range(886, 996):
        for k in range(image1.shape[2]):
            image1[j,i,k] = image2[j,i,k]

# %%
plt.imshow(image1)

# %%
imageio.imwrite("/scratch/data/panel13/clean_inpainted_better2.jpg", image1)
