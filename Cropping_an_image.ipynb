# %%
import imageio
import matplotlib.pyplot as plt

# %%
base_dir = "/scratch/data/panel13"

# %%
image = imageio.imread(base_dir + "/clean_with_pred.png")

# %%
image = image[:-8, :-8, :]

# %%
plt.imshow(image)

# %%
imageio.imwrite(base_dir + "/clean_with_pred.png", image)
