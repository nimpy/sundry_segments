# %%
import imageio
import matplotlib.pyplot as plt

# %%
base_dir = "/scratch/data/panel13"

panel_original = imageio.imread(base_dir + "/clean.tif")
panel_inpainted = imageio.imread(base_dir + "/clean_inpainted_better2.jpg")

detail1_original = imageio.imread(base_dir + "/panel13_cropped1.png")
detail1_inpainted_me = imageio.imread(base_dir + "/panel13_cropped1_20190830_094307_16_8_6755360_10_10_descr_stored.jpg")
detail1_inpainted_them = imageio.imread(base_dir + "/panel13_cropped1_20190908_111139_16_8_6755360_10_10.jpg")

detail2_original = imageio.imread(base_dir + "/panel13_cropped2.png")
detail2_inpainted_me = imageio.imread(base_dir + "/panel13_cropped2_20190902_110352_16_8_6755360_10_10_descr_stored.jpg")
detail2_inpainted_them = imageio.imread(base_dir + "/panel13_cropped2_20190831_235914_16_8_10360_10_10_descr_stored.jpg")

# %%
X = [ (1,2,1), (3,2,2), (3,2,4), (3,2,6) ]
for nrows, ncols, plot_number in X:
    plt.subplot(nrows, ncols, plot_number)
    plt.xticks([])
    plt.yticks([])

# %%
X = [ (1,5,1), (1,5,2), (2,5,3), (2,5,4), (2,5,5), (2,5,8), (2,5,9), (2,5,10) ]
for nrows, ncols, plot_number in X:
    plt.subplot(nrows, ncols, plot_number)
    plt.xticks([])
    plt.yticks([])

# %%
X[0]
# Out:
# (1, 5, 1)

# %%
y_offset_under_big = 0
y_offset_under_small = 0
font_size = 18


fig = plt.figure(figsize=(17, 5))

ax = fig.add_subplot(1,5,1)
ax.axis('off')
ax.set_title('query', y=y_offset_under_big, fontsize=font_size)
ax.imshow(panel_original)

ax = fig.add_subplot(1,5,2)
ax.axis('off')
ax.set_title('query', y=y_offset_under_big, fontsize=font_size)
ax.imshow(panel_inpainted)

ax = fig.add_subplot(2,5,3)
ax.axis('off')
ax.set_title('query', y=y_offset_under_small, fontsize=font_size)
ax.imshow(detail1_original)

ax = fig.add_subplot(2,5,4)
ax.axis('off')
ax.set_title('query', y=y_offset_under_small, fontsize=font_size)
ax.imshow(detail1_inpainted_me)

ax = fig.add_subplot(2,5,5)
ax.axis('off')
ax.set_title('query', y=y_offset_under_small, fontsize=font_size)
ax.imshow(detail1_inpainted_them)

ax = fig.add_subplot(2,5,8)
ax.axis('off')
ax.set_title('query', y=y_offset_under_small, fontsize=font_size)
ax.imshow(detail2_original)

ax = fig.add_subplot(2,5,9)
ax.axis('off')
ax.set_title('query', y=y_offset_under_small, fontsize=font_size)
ax.imshow(detail2_inpainted_me)

ax = fig.add_subplot(2,5,10)
ax.axis('off')
ax.set_title('query', y=y_offset_under_small, fontsize=font_size)
ax.imshow(detail2_inpainted_them)


# fig.savefig(base_dir + "figure1.pdf", bbox_inches='tight')
fig.show()

# %%
y_offset_under_big = -0.07
y_offset_under_small = -0.15
font_size = 17


fig = plt.figure(figsize=(18, 7))

ax = fig.add_subplot(1,4,1)
ax.axis('off')
ax.set_title('original', y=y_offset_under_big, fontsize=font_size)
ax.imshow(panel_original)

ax = fig.add_subplot(1,4,2)
ax.axis('off')
ax.set_title('inpainted with\n proposed descr.', y=2*y_offset_under_big, fontsize=font_size)
ax.imshow(panel_inpainted)

ax = fig.add_subplot(2,6,4)
ax.axis('off')
ax.set_title('original', y=y_offset_under_small, fontsize=font_size)
ax.imshow(detail1_original)

ax = fig.add_subplot(2,6,5)
ax.axis('off')
ax.set_title('inpainted with\n proposed descr.', y=2*y_offset_under_small, fontsize=font_size)
ax.imshow(detail1_inpainted_me)

ax = fig.add_subplot(2,6,6)
ax.axis('off')
ax.set_title('inpainted with\n Chen et al. descr.', y=2*y_offset_under_small, fontsize=font_size)
ax.imshow(detail1_inpainted_them)

ax = fig.add_subplot(2,6,10)
ax.axis('off')
ax.set_title('original', y=y_offset_under_small, fontsize=font_size)
ax.imshow(detail2_original)

ax = fig.add_subplot(2,6,11)
ax.axis('off')
ax.set_title('inpainted with\n proposed descr.', y=2*y_offset_under_small, fontsize=font_size)
ax.imshow(detail2_inpainted_me)

ax = fig.add_subplot(2,6,12)
ax.axis('off')
ax.set_title('inpainted with\n Chen et al. descr.', y=2*y_offset_under_small, fontsize=font_size)
ax.imshow(detail2_inpainted_them)


fig.savefig(base_dir + "/figure1.pdf", bbox_inches='tight', dpi=400)
fig.show()

# %%
y_offset_under_big = -0.07
y_offset_under_small = -0.15
font_size = 17


fig = plt.figure(figsize=(10, 7))

ax = fig.add_subplot(1,2,1)
ax.axis('off')
ax.set_title('original', y=y_offset_under_big, fontsize=font_size)
ax.imshow(panel_original)

ax = fig.add_subplot(1,2,2)
ax.axis('off')
ax.set_title('inpainted with\n proposed descr.', y=2*y_offset_under_big, fontsize=font_size)
ax.imshow(panel_inpainted)




fig.savefig(base_dir + "/figure2.pdf", bbox_inches='tight', dpi=400)
fig.show()

# %%
y_offset_under_big = 0
y_offset_under_small = 0
font_size = 18


fig = plt.figure(figsize=(17, 8))

ax = fig.add_subplot(1,2,1)
ax.axis('off')
ax.set_title('query', y=y_offset_under_big, fontsize=font_size)
ax.imshow(panel_original)

ax = fig.add_subplot(1,2,2)
ax.axis('off')
ax.set_title('query', y=y_offset_under_big, fontsize=font_size)
ax.imshow(panel_inpainted)




# fig.savefig(base_dir + "figure1.pdf", bbox_inches='tight')
fig.show()
