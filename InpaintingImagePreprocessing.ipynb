# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt

# %%
image = imageio.imread('/home/niaki/Code/inpynting_images/Tijana/Jian10/Jian10_degra.png')

# %%
image.shape
# Out:
# (246, 190, 3)

# %%
type(image[0,0,0])
# Out:
# numpy.float64

# %%
image1 = image.astype(np.uint8)

# %%
image2 = image / 255.

# %%
image
# Out:
# Image([[[117.04216496, 132.07229785,  20.52515098],
#         [117.04216496, 132.07229785,  20.52515098],
#         [117.04216496, 132.07229785,  20.52515098],
#         ...,
#         [104.69769187, 121.56485079,  20.52515098],
#         [104.69769187, 120.45324878,  33.8246565 ],
#         [104.69769187, 120.45324878,  33.8246565 ]],
#
#        [[117.04216496, 132.07229785,  20.52515098],
#         [117.04216496, 132.07229785,  20.52515098],
#         [117.04216496, 132.07229785,  20.52515098],
#         ...,
#         [106.01020744, 122.66439452,  28.12967402],
#         [106.01020744, 121.56485079,  38.55165603],
#         [106.01020744, 121.56485079,  38.55165603]],
#
#        [[117.04216496, 131.06682228,  33.8246565 ],
#         [117.04216496, 131.06682228,  33.8246565 ],
#         [117.04216496, 132.07229785,  20.52515098],
#         ...,
#         [106.01020744, 122.66439452,  28.12967402],
#         [106.01020744, 121.56485079,  38.55165603],
# ...

# %%
image1
# Out:
# Image([[[117, 132,  20],
#         [117, 132,  20],
#         [117, 132,  20],
#         ...,
#         [104, 121,  20],
#         [104, 120,  33],
#         [104, 120,  33]],
#
#        [[117, 132,  20],
#         [117, 132,  20],
#         [117, 132,  20],
#         ...,
#         [106, 122,  28],
#         [106, 121,  38],
#         [106, 121,  38]],
#
#        [[117, 131,  33],
#         [117, 131,  33],
#         [117, 132,  20],
#         ...,
#         [106, 122,  28],
#         [106, 121,  38],
#         [106, 121,  38]],
#
#        ...,
#
#        [[160, 162, 109],
#         [160, 162, 109],
#         [160, 162, 109],
#         ...,
#         [174, 173, 115],
#         [175, 174, 117],
#         [176, 176, 119]],
#
#        [[160, 162, 107],
#         [160, 162, 107],
#         [160, 162, 107],
#         ...,
#         [174, 173, 115],
#         [175, 174, 117],
#         [176, 175, 118]],
#
#        [[160, 162, 107],
#         [160, 162, 107],
#         [160, 162, 107],
# ...

# %%
image2
# Out:
# Image([[[0.45898888, 0.51793058, 0.08049079],
#         [0.45898888, 0.51793058, 0.08049079],
#         [0.45898888, 0.51793058, 0.08049079],
#         ...,
#         [0.41057918, 0.47672491, 0.08049079],
#         [0.41057918, 0.47236568, 0.13264571],
#         [0.41057918, 0.47236568, 0.13264571]],
#
#        [[0.45898888, 0.51793058, 0.08049079],
#         [0.45898888, 0.51793058, 0.08049079],
#         [0.45898888, 0.51793058, 0.08049079],
#         ...,
#         [0.4157263 , 0.48103684, 0.11031245],
#         [0.4157263 , 0.47672491, 0.15118296],
#         [0.4157263 , 0.47672491, 0.15118296]],
#
#        [[0.45898888, 0.51398754, 0.13264571],
#         [0.45898888, 0.51398754, 0.13264571],
#         [0.45898888, 0.51793058, 0.08049079],
#         ...,
#         [0.4157263 , 0.48103684, 0.11031245],
#         [0.4157263 , 0.47672491, 0.15118296],
#         [0.4157263 , 0.47672491, 0.15118296]],
#
#        ...,
#
#        [[0.62904325, 0.63828862, 0.43072776],
# ...

# %%
plt.imshow(image/255)

# %%
plt.imshow(image1)

# %%
plt.imshow(image2)

# %%
from PIL import Image

# %%
image_PIL = Image.open('/home/niaki/Code/inpynting_images/Tijana/Jian10/Jian10_degra.png')

# %%
image_PIL
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=190x246 at 0x7FDECD6CE278>

# %%
a = np.asarray(image_PIL)

# %%
a
# Out:
# array([[[ 46,  60,   1],
#         [ 46,  60,   1],
#         [ 46,  60,   1],
#         ...,
#         [ 36,  50,   1],
#         [ 36,  49,   3],
#         [ 36,  49,   3]],
#
#        [[ 46,  60,   1],
#         [ 46,  60,   1],
#         [ 46,  60,   1],
#         ...,
#         [ 37,  51,   2],
#         [ 37,  50,   4],
#         [ 37,  50,   4]],
#
#        [[ 46,  59,   3],
#         [ 46,  59,   3],
#         [ 46,  60,   1],
#         ...,
#         [ 37,  51,   2],
#         [ 37,  50,   4],
#         [ 37,  50,   4]],
#
#        ...,
#
#        [[ 92,  95,  40],
#         [ 92,  95,  40],
#         [ 92,  95,  40],
#         ...,
#         [111, 110,  45],
#         [112, 111,  46],
#         [114, 113,  48]],
#
#        [[ 92,  95,  38],
#         [ 92,  95,  38],
#         [ 92,  95,  38],
#         ...,
#         [111, 110,  45],
#         [112, 111,  46],
#         [113, 112,  47]],
#
#        [[ 92,  95,  38],
#         [ 92,  95,  38],
#         [ 92,  95,  38],
# ...

# %%
imageio.imsave('/home/niaki/Code/inpynting_images/Tijana/Jian10_uint8/Jian10_degra.png', a)

# %%
im2
