# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt

# %%
image = imageio.imread('/home/niaki/Code/inpynting_images/Tijana/Jian10/Jian10_degra.png')

# %%
image.shape
# Out:
# (246, 190, 3)

# %%
type(image[0,0,0])
# Out:
# numpy.float64

# %%
image1 = image.astype(np.uint8)

# %%
image2 = image / 255.

# %%
image
# Out:
# Image([[[117.04216496, 132.07229785,  20.52515098],
#         [117.04216496, 132.07229785,  20.52515098],
#         [117.04216496, 132.07229785,  20.52515098],
#         ...,
#         [104.69769187, 121.56485079,  20.52515098],
#         [104.69769187, 120.45324878,  33.8246565 ],
#         [104.69769187, 120.45324878,  33.8246565 ]],
#
#        [[117.04216496, 132.07229785,  20.52515098],
#         [117.04216496, 132.07229785,  20.52515098],
#         [117.04216496, 132.07229785,  20.52515098],
#         ...,
#         [106.01020744, 122.66439452,  28.12967402],
#         [106.01020744, 121.56485079,  38.55165603],
#         [106.01020744, 121.56485079,  38.55165603]],
#
#        [[117.04216496, 131.06682228,  33.8246565 ],
#         [117.04216496, 131.06682228,  33.8246565 ],
#         [117.04216496, 132.07229785,  20.52515098],
#         ...,
#         [106.01020744, 122.66439452,  28.12967402],
#         [106.01020744, 121.56485079,  38.55165603],
# ...

# %%
image1
# Out:
# Image([[[117, 132,  20],
#         [117, 132,  20],
#         [117, 132,  20],
#         ...,
#         [104, 121,  20],
#         [104, 120,  33],
#         [104, 120,  33]],
#
#        [[117, 132,  20],
#         [117, 132,  20],
#         [117, 132,  20],
#         ...,
#         [106, 122,  28],
#         [106, 121,  38],
#         [106, 121,  38]],
#
#        [[117, 131,  33],
#         [117, 131,  33],
#         [117, 132,  20],
#         ...,
#         [106, 122,  28],
#         [106, 121,  38],
#         [106, 121,  38]],
#
#        ...,
#
#        [[160, 162, 109],
#         [160, 162, 109],
#         [160, 162, 109],
#         ...,
#         [174, 173, 115],
#         [175, 174, 117],
#         [176, 176, 119]],
#
#        [[160, 162, 107],
#         [160, 162, 107],
#         [160, 162, 107],
#         ...,
#         [174, 173, 115],
#         [175, 174, 117],
#         [176, 175, 118]],
#
#        [[160, 162, 107],
#         [160, 162, 107],
#         [160, 162, 107],
# ...

# %%
image2
# Out:
# Image([[[0.45898888, 0.51793058, 0.08049079],
#         [0.45898888, 0.51793058, 0.08049079],
#         [0.45898888, 0.51793058, 0.08049079],
#         ...,
#         [0.41057918, 0.47672491, 0.08049079],
#         [0.41057918, 0.47236568, 0.13264571],
#         [0.41057918, 0.47236568, 0.13264571]],
#
#        [[0.45898888, 0.51793058, 0.08049079],
#         [0.45898888, 0.51793058, 0.08049079],
#         [0.45898888, 0.51793058, 0.08049079],
#         ...,
#         [0.4157263 , 0.48103684, 0.11031245],
#         [0.4157263 , 0.47672491, 0.15118296],
#         [0.4157263 , 0.47672491, 0.15118296]],
#
#        [[0.45898888, 0.51398754, 0.13264571],
#         [0.45898888, 0.51398754, 0.13264571],
#         [0.45898888, 0.51793058, 0.08049079],
#         ...,
#         [0.4157263 , 0.48103684, 0.11031245],
#         [0.4157263 , 0.47672491, 0.15118296],
#         [0.4157263 , 0.47672491, 0.15118296]],
#
#        ...,
#
#        [[0.62904325, 0.63828862, 0.43072776],
# ...

# %%
plt.imshow(image/255)

# %%
plt.imshow(image1)

# %%
plt.imshow(image2)

# %%
from PIL import Image

# %%
image_PIL = Image.open('/home/niaki/Code/inpynting_images/Tijana/Jian9/Jian9_degra.png')

# %%
image_PIL
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=259x274 at 0x7F3FAFE3EFD0>

# %%
a = np.asarray(image_PIL)

# %%
a
# Out:
# array([[[239, 255, 255],
#         [239, 255, 255],
#         [239, 255, 255],
#         ...,
#         [239, 255, 255],
#         [240, 255, 255],
#         [240, 255, 255]],
#
#        [[240, 255, 255],
#         [240, 255, 255],
#         [239, 255, 255],
#         ...,
#         [239, 255, 255],
#         [240, 255, 255],
#         [240, 255, 255]],
#
#        [[239, 255, 255],
#         [239, 255, 255],
#         [239, 255, 255],
#         ...,
#         [239, 255, 255],
#         [239, 255, 255],
#         [239, 255, 255]],
#
#        ...,
#
#        [[ 74,  85,  81],
#         [ 80,  90,  89],
#         [ 79,  89,  88],
#         ...,
#         [ 87,  97,  99],
#         [ 94, 104, 106],
#         [ 93, 103, 105]],
#
#        [[ 75,  86,  82],
#         [ 74,  84,  83],
#         [ 72,  82,  81],
#         ...,
#         [ 85,  95,  97],
#         [ 91, 101, 103],
#         [ 78,  88,  90]],
#
#        [[ 79,  89,  88],
#         [ 78,  88,  87],
#         [ 71,  81,  80],
# ...

# %%
imageio.imsave('/home/niaki/Code/inpynting_images/Tijana/Jian9_uint8/Jian9_degra.png', a)

# %%
im2
