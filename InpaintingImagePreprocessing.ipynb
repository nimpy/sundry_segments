# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt

# %%
image = imageio.imread('/home/niaki/Code/inpynting_images/Tijana/Jian1/Jian1.png')

# %%
image.shape
# Out:
# (307, 281, 3)

# %%
type(image[0,0,0])
# Out:
# numpy.uint8

# %%
image1 = image.astype(np.uint8)

# %%
image2 = image / 255.

# %%
image
# Out:
# Array([[[161, 166, 170],
#         [161, 166, 170],
#         [162, 167, 171],
#         ...,
#         [188, 191, 196],
#         [189, 193, 196],
#         [190, 194, 197]],
#
#        [[162, 167, 171],
#         [162, 165, 170],
#         [163, 166, 171],
#         ...,
#         [189, 192, 197],
#         [189, 192, 197],
#         [189, 192, 197]],
#
#        [[161, 166, 170],
#         [162, 165, 170],
#         [162, 165, 170],
#         ...,
#         [191, 192, 197],
#         [190, 191, 196],
#         [190, 191, 196]],
#
#        ...,
#
#        [[ 26,  19,   9],
#         [ 25,  22,  13],
#         [ 23,  19,  10],
#         ...,
#         [ 50,  36,  27],
#         [ 51,  37,  28],
#         [ 50,  36,  27]],
#
#        [[ 31,  24,  14],
#         [ 22,  22,  12],
#         [ 26,  22,  13],
#         ...,
#         [ 50,  37,  28],
#         [ 49,  36,  27],
#         [ 47,  34,  25]],
#
#        [[ 26,  22,  11],
#         [ 16,  17,   9],
#         [ 27,  24,  15],
# ...

# %%
image1
# Out:
# Array([[[161, 166, 170],
#         [161, 166, 170],
#         [162, 167, 171],
#         ...,
#         [188, 191, 196],
#         [189, 193, 196],
#         [190, 194, 197]],
#
#        [[162, 167, 171],
#         [162, 165, 170],
#         [163, 166, 171],
#         ...,
#         [189, 192, 197],
#         [189, 192, 197],
#         [189, 192, 197]],
#
#        [[161, 166, 170],
#         [162, 165, 170],
#         [162, 165, 170],
#         ...,
#         [191, 192, 197],
#         [190, 191, 196],
#         [190, 191, 196]],
#
#        ...,
#
#        [[ 26,  19,   9],
#         [ 25,  22,  13],
#         [ 23,  19,  10],
#         ...,
#         [ 50,  36,  27],
#         [ 51,  37,  28],
#         [ 50,  36,  27]],
#
#        [[ 31,  24,  14],
#         [ 22,  22,  12],
#         [ 26,  22,  13],
#         ...,
#         [ 50,  37,  28],
#         [ 49,  36,  27],
#         [ 47,  34,  25]],
#
#        [[ 26,  22,  11],
#         [ 16,  17,   9],
#         [ 27,  24,  15],
# ...

# %%
image2
# Out:
# Array([[[0.63137255, 0.65098039, 0.66666667],
#         [0.63137255, 0.65098039, 0.66666667],
#         [0.63529412, 0.65490196, 0.67058824],
#         ...,
#         [0.7372549 , 0.74901961, 0.76862745],
#         [0.74117647, 0.75686275, 0.76862745],
#         [0.74509804, 0.76078431, 0.77254902]],
#
#        [[0.63529412, 0.65490196, 0.67058824],
#         [0.63529412, 0.64705882, 0.66666667],
#         [0.63921569, 0.65098039, 0.67058824],
#         ...,
#         [0.74117647, 0.75294118, 0.77254902],
#         [0.74117647, 0.75294118, 0.77254902],
#         [0.74117647, 0.75294118, 0.77254902]],
#
#        [[0.63137255, 0.65098039, 0.66666667],
#         [0.63529412, 0.64705882, 0.66666667],
#         [0.63529412, 0.64705882, 0.66666667],
#         ...,
#         [0.74901961, 0.75294118, 0.77254902],
#         [0.74509804, 0.74901961, 0.76862745],
#         [0.74509804, 0.74901961, 0.76862745]],
#
#        ...,
#
#        [[0.10196078, 0.0745098 , 0.03529412],
# ...

# %%
plt.imshow(image/255)

# %%
plt.imshow(image1)

# %%
plt.imshow(image2)

# %%
from PIL import Image

# %%
image_PIL = Image.open('/home/niaki/Code/inpynting_images/Tijana/Jian10/Jian10.png')

# %%
image_PIL
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=190x246 at 0x7F4D64C3AD68>

# %%
a = np.asarray(image_PIL)

# %%
a
# Out:
# array([[[ 46,  60,   1],
#         [ 46,  60,   1],
#         [ 46,  60,   1],
#         ...,
#         [ 36,  50,   1],
#         [ 36,  49,   3],
#         [ 36,  49,   3]],
#
#        [[ 46,  60,   1],
#         [ 46,  60,   1],
#         [ 46,  60,   1],
#         ...,
#         [ 37,  51,   2],
#         [ 37,  50,   4],
#         [ 37,  50,   4]],
#
#        [[ 46,  59,   3],
#         [ 46,  59,   3],
#         [ 46,  60,   1],
#         ...,
#         [ 37,  51,   2],
#         [ 37,  50,   4],
#         [ 37,  50,   4]],
#
#        ...,
#
#        [[ 92,  95,  40],
#         [ 92,  95,  40],
#         [ 92,  95,  40],
#         ...,
#         [111, 110,  45],
#         [112, 111,  46],
#         [114, 113,  48]],
#
#        [[ 92,  95,  38],
#         [ 92,  95,  38],
#         [ 92,  95,  38],
#         ...,
#         [111, 110,  45],
#         [112, 111,  46],
#         [113, 112,  47]],
#
#        [[ 92,  95,  38],
#         [ 92,  95,  38],
#         [ 92,  95,  38],
# ...

# %%
imageio.imsave('/home/niaki/Code/inpynting_images/Tijana/Jian10_uint8/Jian10.png', a)

# %%
im2
