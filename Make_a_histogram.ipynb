# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt

# %%
patch = imageio.imread("/home/niaki/Downloads/IMG_20200820_113851_crop_patch.jpg")

# %%
patch.shape
# Out:
# (130, 130)

# %%
patch.flatten()
# Out:
# Image([ 24,  36,  68, ..., 217, 214, 208], dtype=uint8)

# %%
plt.figure(figsize=(20,8))
plt.hist(patch.flatten(), bins=20, color="black")
plt.axis("off")
plt.savefig('/home/niaki/Downloads/patch_histogram.png')
