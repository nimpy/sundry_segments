# %%
import matplotlib.pyplot as plt

# %%
ds_size = [100,       500,      1000,       5000,      10000,      15000,      20000]

# %%
lb_easy = [0.715684,  0.568863,  0.511152,  0.387703,  0.341406,   0.315867,   0.301088]
lb_hard = [0.563232,  0.370063,  0.306179,  0.192707,  0.157413,   0.139811,   0.129491]
lb_tough =[0.437682,  0.245143,  0.191431,  0.104206,  0.0805194,  0.0692609,  0.0630245]

# %%
ob_easy = [0.607637,  0.459154,  0.40329,   0.298429,   0.261381,   0.241909,   0.229577]
ob_hard = [0.417613,  0.246846,  0.196991,  0.118796,   0.0959675,  0.0851197,  0.078811]
ob_tough =[0.281406,  0.136621,  0.101037,  0.0527598,  0.04088,    0.035591,   0.0324161]

# %%
diff_easy = [0.108047, 0.109709, 0.107862, 0.089274, 0.080025, 0.073958, 0.071511]
diff_hard = [0.145619, 0.123217, 0.109188, 0.073911, 0.0614455, 0.0546913, 0.05068]
diff_tough = [0.156276, 0.108522, 0.090394, 0.0514462, 0.0396394, 0.0336699, 0.0306084]

# %%
# plt.plot(ds_size, lb_easy, '-o', label="Learned BRIEF easy")
# plt.plot(ds_size, lb_hard, '--o', label="Learned BRIEF hard")
# plt.plot(ds_size, lb_tough, ':o', label="Learned BRIEF tough")
plt.plot(ds_size, ob_easy, 'b-x', label="BRIEF easy")
plt.plot(ds_size, ob_hard, 'b--x', label="BRIEF hard")
plt.plot(ds_size, ob_tough, 'b:x', label="BRIEF tough")
plt.plot(ds_size, lb_easy, 'r-o', label="Learned BRIEF easy")
plt.plot(ds_size, lb_hard, 'r--o', label="Learned BRIEF hard")
plt.plot(ds_size, lb_tough, 'r:o', label="Learned BRIEF tough")
plt.legend(loc="upper right")
plt.xlabel('Test dataset size')#, fontsize=18)
plt.ylabel('mAP')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(ds_size, ob_easy, 'b-s', label="BRIEF easy")
plt.plot(ds_size, ob_hard, 'b-o', label="BRIEF hard")
plt.plot(ds_size, ob_tough, 'b-x', label="BRIEF tough")
plt.plot(ds_size, lb_easy, 'r-s', label="Learned BRIEF easy")
plt.plot(ds_size, lb_hard, 'r-o', label="Learned BRIEF hard")
plt.plot(ds_size, lb_tough, 'r-x', label="Learned BRIEF tough")
plt.legend(loc="upper right",fontsize=15)
plt.xlabel('Size of the pool of patches', fontsize=15)
plt.ylabel('mAP', fontsize=15)
# plt.show()
plt.savefig("/home/niaki/Downloads/hpatches_retrieval_plt2.pdf", bbox_inches='tight')

# %%
# ended up using this one

plt.figure(figsize=(8,6))
# plt.plot(ds_size, ob_easy, linestyle='-', marker='s', color='#1f77b4', label="BRIEF easy")
# plt.plot(ds_size, ob_hard, linestyle='-', marker='o', color='#1f77b4', label="BRIEF hard")
# plt.plot(ds_size, ob_tough, linestyle='-', marker='x', color='#1f77b4', label="BRIEF tough")
plt.plot(ds_size, ob_easy, 'b--s', label="BRIEF easy")
plt.plot(ds_size, ob_hard, 'b--o', label="BRIEF hard")
plt.plot(ds_size, ob_tough, 'b--x', label="BRIEF tough")
plt.plot(ds_size, lb_easy, linestyle='-', marker='s', color='#ff7f0e', label="Learned BRIEF easy")
plt.plot(ds_size, lb_hard, linestyle='-', marker='o', color='#ff7f0e', label="Learned BRIEF hard")
plt.plot(ds_size, lb_tough, linestyle='-', marker='x', color='#ff7f0e', label="Learned BRIEF tough")
plt.legend(loc="upper right",fontsize=15)
plt.xlabel('Size of the pool of patches', fontsize=15)
plt.ylabel('mAP', fontsize=15)
# plt.show()
plt.savefig("/home/niaki/Downloads/hpatches_retrieval_plt4.pdf", bbox_inches='tight')

# %%
plt.plot(ds_size, ob_easy, linestyle='-s', label="BRIEF easy", color='c0')

# %%
plt.plot(ds_size, ob_easy, '-x', label="BRIEF easy")
# plt.plot(ds_size, ob_hard, '--x', label="BRIEF hard")
# plt.plot(ds_size, ob_tough, ':x', label="BRIEF tough")
plt.plot(ds_size, lb_easy, '-o', label="Learned BRIEF easy")
# plt.plot(ds_size, lb_hard, '--o', label="Learned BRIEF hard")
# plt.plot(ds_size, lb_tough, ':o', label="Learned BRIEF tough")
plt.legend(loc="upper right")
plt.xlabel('Test dataset size')#, fontsize=18)
plt.ylabel('mAP')
plt.show()

# %%
# plt.plot(ds_size, ob_easy, '-x', label="BRIEF easy")
plt.plot(ds_size, ob_hard, '--x', label="BRIEF hard")
# plt.plot(ds_size, ob_tough, ':x', label="BRIEF tough")
# plt.plot(ds_size, lb_easy, '-o', label="Learned BRIEF easy")
plt.plot(ds_size, lb_hard, '--o', label="Learned BRIEF hard")
# plt.plot(ds_size, lb_tough, ':o', label="Learned BRIEF tough")
plt.legend(loc="upper right")
plt.xlabel('Test dataset size')#, fontsize=18)
plt.ylabel('mAP')
plt.show()

# %%
plt.plot(ds_size, diff_easy, '-o', label="easy")
plt.plot(ds_size, diff_hard, '--s', label="hard")
plt.plot(ds_size, diff_tough, ':^', label="tough")
plt.legend(loc="upper right")
plt.xlabel('Test dataset size')#, fontsize=18)
plt.ylabel('Difference (mAP)')
plt.show()
