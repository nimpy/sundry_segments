# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import imageio

# %%
image = imageio.imread("/home/niaki/Code/inpynting_images/Tijana/Jian1_uint8_downscaled/Jian_small_1_degra2.png")

# %%
fig, ax = plt.subplots(1)
ax.imshow(image)


rect = patches.Rectangle((0, 0),
                        16, 16, linewidth=1, edgecolor='r', facecolor='none')
ax.add_patch(rect)
plt.show()
