# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
marked_txtr0 = np.load('/scratch/panfilov/marked_textures/0_no.npy')

# %%
plt.imshow(marked_txtr0 - 1)

# %%
marked_txtr9129 = np.load('/scratch/panfilov/marked_textures/9129_yes.npy')

# %%
plt.imshow(marked_txtr9129 - 1)

# %%
# spiral wave trajectory coordinates

# %%
cores_pickle_filepath = '/scratch/panfilov/OriginalTextures/OriginalArrhythmogenic/exp999/cores.pickle'

with open(cores_pickle_filepath, 'rb') as pickle_file:
    content = pickle.load(pickle_file)

# %%
len(content)
# Out:
# 3

# %%
content[0]
# Out:
# [array([202, 210, 201, 200, 216, 217, 218, 211, 212, 213, 213, 217, 216,
#         204, 207]),
#  array([27, 42, 58, 58, 46, 43, 35, 31, 41, 50, 50, 44, 44, 29, 28])]

# %%
content[1]
# Out:
# [array([55, 59, 41, 39, 40, 55, 55, 56, 54, 39, 37, 38, 55, 52, 56]),
#  array([120, 116, 113, 110, 108, 111, 111, 119, 122, 115, 110, 108, 111,
#         110, 123])]

# %%
content[2]
# Out:
# [array([ 72,  85,  74,  73, 102,  88,  88,  76,  76, 103]),
#  array([153, 154, 161, 161, 137, 153, 152, 158, 158, 134])]

# %%
orig_txtr999 = np.load('/scratch/panfilov/OriginalTextures/OriginalArrhythmogenic/exp999/texture.npy')
orig_txtr999_crop = orig_txtr999[1: -1, 1: -1]

# %%
# plt.figure(figsize=(15,15))
plt.imshow(orig_txtr999_crop - 1)

# %%
np.max(orig_txtr999_crop)
# Out:
# 2.0
