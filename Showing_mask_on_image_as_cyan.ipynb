# %%
import imageio
import matplotlib.pyplot as plt

# %%
image = imageio.imread("/scratch/data/panel13/clean.tif")
mask = imageio.imread("/scratch/data/panel13/pred.png")

# %%
cyan = [0, 255, 255]
image[mask.astype(bool), :] = cyan

# %%
plt.imshow(image)

# %%
imageio.imwrite("/scratch/data/panel13/clean_with_pred.png", image)
