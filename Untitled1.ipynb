# %%
import imageio
import matplotlib.pyplot as plt

# %%
image = imageio.imread("/scratch/data/hand/clean.tif")
mask = imageio.imread("/scratch/data/hand/pred.tif")

# %%
image.shape
# Out:
# (1401, 2101, 3)

# %%
cropped_size = 620
cropped_x = 216
cropped_y = 1041
image_cropped = image[cropped_x: cropped_x + cropped_size, cropped_y: cropped_y + cropped_size, : ]
mask_cropped = mask[cropped_x: cropped_x + cropped_size, cropped_y: cropped_y + cropped_size]

# %%
plt.imshow(image_cropped)

# %%
plt.imshow(mask_cropped)

# %%
imageio.imwrite("/scratch/data/hand/hand_cropped1.png", image_cropped)
imageio.imwrite("/scratch/data/hand/hand_mask_cropped1.png", mask_cropped)
