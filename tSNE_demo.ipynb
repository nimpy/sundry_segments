# %%
import pandas as pd
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt

# %%
descrs = pd.read_csv('/home/niaki/temp/20210318_making_t_SNE_plot/e1.csv')
descrs = descrs.to_numpy()

# %%
tsne = TSNE(n_components=2, random_state=0)

# %%
descrs_2d = tsne.fit_transform(descrs)

# %%
descrs_2d.shape
# Out:
# (344, 2)

# %%
plt.scatter(descrs_2d[:,0], descrs_2d[:,1])
